# %% [markdown]
# # Katas del módulo 2

# %%
pip install virtualenv
# Out:
# Requirement already satisfied: virtualenv in /Users/oepr/opt/anaconda3/lib/python3.8/site-packages (20.13.1)
# Requirement already satisfied: distlib<1,>=0.3.1 in /Users/oepr/opt/anaconda3/lib/python3.8/site-packages (from virtualenv) (0.3.4)
# Requirement already satisfied: platformdirs<3,>=2 in /Users/oepr/opt/anaconda3/lib/python3.8/site-packages (from virtualenv) (2.5.0)
# Requirement already satisfied: filelock<4,>=3.2 in /Users/oepr/opt/anaconda3/lib/python3.8/site-packages (from virtualenv) (3.4.2)
# Requirement already satisfied: six<2,>=1.9.0 in /Users/oepr/opt/anaconda3/lib/python3.8/site-packages (from virtualenv) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Este código se ejecuta desde terminal.
#
#
# *virtualenv venv*
#
# ![image.png](attachment:image.png)
#
# Activar el ambiente virtual
#
# *source venv/bin/activate*
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# *pip freeze*
#
# *pip install python-dateutil*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Desactivar el ambiente virtual
#
# *deactivate*
